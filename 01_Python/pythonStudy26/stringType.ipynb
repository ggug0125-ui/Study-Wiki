# %%
from calendar import month
from getopt import short_has_arg
from platform import python_branch
from selectors import SelectSelector

from prompt_toolkit.contrib.telnet import TelnetServer

# 문자열(string) 자료형
# 연속된 문자들을 나열 한다.
# 큰 따옴표, 작은 따옴표 안에 작성된 모든 글자를 문자열로 취급함
# 따옴표로 만든 값은 직접 계산하면 안됨
kor = "100"
mat = "100"
eng = "100"
total = kor + mat + eng
print(total)
# Out:
# 100100100

# %%
food = "python's favorite food is perl"
print(food)
# Out:
# python's favorite food is perl

# %%
food = "python's favorite food is perl"
file "<stdin>", line 1
print(file)
# Out:
#   Cell In[96], line 2
#     file "<stdin>", line 1
#          ^
# SyntaxError: invalid syntax

# %%
say = '"python is very easy." he says.' #큰따옴표 포함된 문자열을 작은따옴표로 둘러싸면 된다
print(say)

# %%
food = 'python\'s favorite food is perl' # 다른방법은 역슬래시(\)사용
say = "\"python is very easy.\" he say."
print(say)
print(food)

# %%
say = "Life is too short. You need python"

print(say)

# %%
multiline = '''
Life is too short
You need python
    '''
print(multiline)

# %%
multiline = """
Life is too short
You need python
"""
print(multiline)

# %%
head = "python"
tail = " is fun!!!"
say = head + tail
print(say)

# %%
a = "python"
say = a * 2
print(say)

# %%
#multistring.py
print("=" * 50)
print("my program")
print("=" * 50)

# %%
#multistring.py
print("$" * 50)
print("lim hyo jung")
print("$" * 50)

# %%
#문자열은 더하기 식이 진행되면 글자를 붙임!!!
a = "hello 'MBC' world"
print(a)

# %%
b = 'python is "fun"'
print(b)

# %%
c = """life is too short,
You need python
kkw"""
print(c)
# Out:
# life is too short,
# You need python
# kkw

# %%
menu = "환영합니다. 'mbc' 아카데미 성적처리 프로그램입니다"
subMenu = "1, 학생등록 . 2.성적처리, 3. 성적보기 4.종료"
print(menu)
print(subMenu)
# Out:
# 환영합니다. 'mbc' 아카데미 성적처리 프로그램입니다
# 1, 학생등록 . 2.성적처리, 3. 성적보기 4.종료

# %%
menu = """
===========================================
환영합니다. 'MBC' 아카데미 성적처리 프로그램입니다.
===========================================
 1. 학생등록
 2. 성적처리
 3. 성적보기
 4. 종료

 """
print(menu)
# Out:
# ...
# 환영합니다. 'MBC' 아카데미 성적처리 프로그램입니다.
# ...
#  1. 학생등록
#  2. 성적처리
#  3. 성적보기
#  4. 종료

# %%
submenu1 = '''
==========================================
학생메뉴로 진입하였습니다.
1. 학생전체보기
2. 학생자세히보기
3. 학생수정하기
4. 학생삭제하기
5. 상위메뉴로 진입

'''
print(submenu1)
# Out:
# ...
# 학생메뉴로 진입하였습니다.
# 1. 학생전체보기
# 2. 학생자세히보기
# 3. 학생수정하기
# 4. 학생삭제하기
# 5. 상위메뉴로 진입

# %%
submenu2 = "===============================\n성적처리 메뉴로 진입하셨습니다. \n 1. 학생성적등록 \n 2. 학생전체성적보기 \n 3. 학생개인성적보기 \n 4. 학생성적수정 \n 5. 학생자료백업 \n 6. 상위메뉴"
print(submenu2)
# Out:
# ...
# 성적처리 메뉴로 진입하셨습니다.
#  1. 학생성적등록
#  2. 학생전체성적보기
#  3. 학생개인성적보기
#  4. 학생성적수정
#  5. 학생자료백업
#  6. 상위메뉴

# %%
# menu3.py 파일을 생성하고 print안쪽에 "="*15 하면
# =이 15번 반복하는 것을 볼 수 있다.
# 터미널메뉴 파일을 불러올때 .\를 눌러 파일을 불러오기한다

# %%
# 문자열의 길이를 구하는 len()함수가 있다.
# 입력된 주민번호 글자수를 알아내는 코드
# id/pw에 대한 글자수 검증용으로 활용할 수 있다.

inputSsn = "120604-2345678"
type(inputSsn) #숫자인지 문자인지 구분 및 검증하는 용도(type)
# Out:
# str

# %%
len(inputSsn) #len 글자수
# Out:
# 14

# %%
if len(inputSsn)==14 :
    print("주민번호 14글자가 잘 입력 되었습니다.") #참 true
else:
    print("주민번호 14글자가 잘못 입력 되었습니다.") # 거짓 False
# Out:
# 주민번호 14글자가 잘 입력 되었습니다.

# %%
# 문자열 인덱싱은 문자를 표로 만들어 0번부터 주소를 넣은 값
# 문자열 슬라이싱은 문자를 인덱스를 잘라 가져옴!
word = "life is too short, You need python"
#       012345678910                     33

# %%
word[3] #word 변수의 3번째 문자열
# Out:
# 'e'

# %%
word[-1] #인덱스에 -값은 뒤에서부터 ~
# Out:
# 'n'

# %%
word[-3]
# Out:
# 'h'

# %%
#변수[시작:-1끝] 끝번호는 해당문자를 포함하지 않음.! [0:4] 문자열 0~3까지 프린트됨
# word[0:3] => 0 <= a < 3
word[0:3] #0부터 3이전까지
# Out:
# 'lif'

# %%
#주민번호 앞 2자리를 생년으로 추출하고 yesr
#주민번호 3~4자리를 생월로 추출 month
#주민번호 5~6자리흫 생일로 추출 day
#주민번호 8번째 1자리를 남여 추출 sex

# %%
inputSsn[0:2]
year = inputSsn[0:2]

# %%
year = inputSsn[0:2]

# %%
inputSsn = "120604-2345678"
year = inputSsn[0:2]
month = inputSsn[2:4]
day = inputSsn[4:6]
ssnNumber = inputSsn[7]
ssnNumber = int(ssnNumber)
type(ssnNumber)
# Out:
# int

# %%
print("귀하의 생년은 " + year + "년")
print("귀하의 생월은 " + month + "월")
print("귀하의 생일은 " + day + "일 입니다.")
# Out:
# 귀하의 생년은 12년
# 귀하의 생월은 06월
# 귀하의 생일은 04일 입니다.

# %%
# 미션 주민번호 8번째 글자가 1,2,5,6이면 1900년 생
# 3,4,7,8이면 2000년 생으로 만들어!!

# %%
if ssnNumber == 1 :
    yearif = "19"+year # 문자인경우  + 기호는 붙임
elif ssnNumber == 2 :
    yearif = "19"+year
elif ssnNumber == 5 :
    yearif = "19"+year
elif ssnNumber == 6 :
    yearif = "19"+year
elif ssnNumber == 9 :
    print("당신은 외계인입니다.")
else:
    yearif = "20"+year
print(yearif)
# Out:
# 1912

# %%
# 8~9번째
#서울 00-08 부산 09-12 인천13-15
#경기 16-25 강원 26-34 충청 35-47
#전라 48-66 경상 67-91 제주 92-95

# %%
a = "pithon"
a[:1]
a[2:]
a[:1] + "y" + a[2:]
# Out:
# 'python'

# %%
"i eat %d apples." %3
# Out:
# 'i eat 3 apples.'

# %%
"I eat %s apples." %"five"
# Out:
# 'I eat five apples.'

# %%
number = 10
day = "three"
" I ate %d apples. so I was sick for %s day." %(number,day)
# Out:
# ' I ate 10 apples. so I was sick for three day.'

# %%
"I have %s apples" %3
# Out:
# 'I have 3 apples'

# %%
"rate is %s" %3.234
# Out:
# 'rate is 3.234'

# %%
"Error is %d%%." %98 # %는 두번연속으로 찍어야함
# Out:
# 'Error is 98%.'

# %%
"%10s" %"hi" # 10칸 띄고 hi
# Out:
# '        hi'

# %%
"%-10sjane." %'hi' #제인 앞으로 10칸
# Out:
# 'hi        jane.'

# %%
"%0.4f" % 3.42134234 #소수점 표현
# Out:
# '3.4213'

# %%
"%10.4f" %3.42134234 #10.4라는건 10칸안에 소수점 4자리까지 출력하는것
# Out:
# '    3.4213'

# %%
"i eat {0} apples". format("five")
# Out:
# 'i eat five apples'

# %%
number = 3
"I eat {0} apples".format(number)
# Out:
# 'I eat 3 apples'

# %%
"I ate {number} apples. so I was sick for {day} day.".format(number=10,day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 day.'

# %%
"{0:<10}".format("hi") # 0에서 10칸보다 작은곳에 hi 왼쪽정렬
# Out:
# 'hi        '

# %%
"{0:^10}".format("hi") # 0에서 10칸 정가운데에 hi
# Out:
# '    hi    '

# %%
"{0:=^10}".format("hi") # 0에서 빈칸을 =으로 표시후 가운데에 hi
# Out:
# '====hi===='

# %%
"{0:!<10}".format("hi") # 0에서 10칸보다 작은곳에 hi쓰고 빈칸 !!
# Out:
# 'hi!!!!!!!!'

# %%
y = 3.42134234
"{0:0.4f}".format(y)  #0.4는 소수점 4자리까지 표현
# Out:
# '3.4213'

# %%
y = 3.42134234
"{0:10.4f}".format(y) #10칸안에 소수점4자리까지 표현
# Out:
# '    3.4213'

# %%
name = '홍길동'
age = 30
f'나의 이름은 {name}입니다. 나이는 {age}입니다.'      #  f문자열 포매팅
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
# f문자열 포매팅 - 파이썬 3.6미만 버전에는 사용할수없음 출력용으로 간단히 쓸수있다{a+1} 계산도 가능
age = 30
f'나는 내년이면 {age + 1}살이 된다.'
# Out:
# '나는 내년이면 31살이 된다.'

# %%
d = {'name':'홍길동', 'age':30} #이걸 왜 뽑아오지?? 딕셔너리 안배워 모름 -자료뽑아올때 쓰나봄
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
# 정렬하기
f'{"hi":<10}'   #왼쪽정렬
# Out:
# 'hi        '

# %%
f'{"hi":>10}'  #오른쪽 정렬
# Out:
# '        hi'

# %%
f'{"hi":^10}'  #가운데 정렬
# Out:
# '    hi    '

# %%
f'{"hi":=^10}'
# Out:
# '====hi===='

# %%
f'{"hi":!<10}'
# Out:
# 'hi!!!!!!!!'

# %%
f"난 {1500000:,}원이 필요해" #숫자 콤마 찍어주기
# Out:
# '난 1,500,000원이 필요해'

# %%
#함수  count  문자 숫자세기 카운트!!
a = "hobby"
a.count('b')
# Out:
# 2

# %%
#함수  find  문자 자리위치 찾아주기, 문자가 존재하지 않을경우 -1로 표시됨
a = "python is the best choice"
a.find('b')
# Out:
# 14

# %%
a.find('k')  # 찾는문자 없을시 -1로 표시 기억하기~!!
# Out:
# -1

# %%
# 함수  index #문자 자리찾아주기 find와 동일하지만 문자가 없을경우 -1로 표시되지않고 오류가 발생된다
a = "Life is too short"
a.index('t')
# Out:
# 8

# %%
a.index('k') # 찾는 문자없을시 에러남
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 a.index('k')
#
# ValueError: substring not found

# %%
# 함수  join  삽입기능
",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
# 함수 upper  소문자를 대문자로 바꾸기 ** 변수를 만들어 항상 ( a = a.upper()) 변수만들어 사용하기
a = "hi"
a.upper()
# Out:
# 'HI'

# %%
# 함수 lower 대문자를 소문자로 바꾸기
a = "HI"
a.lower()
# Out:
# 'hi'

# %%
# 함수 lstrip  왼쪽 공백지우기
a = "     hi  "
a.lstrip()
# Out:
# 'hi  '

# %%
# 함수 retrip 오른쪽 공백 지우기
a = "  hi       "
a.rstrip()
# Out:
# '  hi'

# %%
# 함수 strip 양쪽공백 지우기
a = "        hi        "
a.strip()
# Out:
# 'hi'

# %%
# 함수   replace  문자열을 바꿀때 사용 (효정=>동식으로 수정시)
a = "Life is too short"
a.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %%
# 함수  split  문자열나누기 단어를 나눠준다(많이쓰임)
a = "Life is too short"
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
# 함수 isalpha 영문 알파벳만 있는지 오류검토     True, 공백이나 숫자 문자가 있는경우 False
s = "python"
s.isalpha()
# Out:
# True

# %%
s = "python3"
s.isalpha()
# Out:
# False

# %%
s = " python good"
s.isalpha()
# Out:
# False

# %%
# 함수 isdigit  숫자만 있는지 오류 검토 True, 공백이나 영문 문자가 있는경우 False
s = "12345"
s.isdigit()
# Out:
# True

# %%
s = "1234a"
s.isdigit()
# Out:
# False

# %%
s = "12  34"
s.isdigit()
# Out:
# False

# %%
#함수 startswith  지정한문자로 시작하는지 검토 지정문자이면 True, 아니면 False
s = "Life is too short"
s.startswith("Life")
# Out:
# True

# %%
s.startswith("short")
# Out:
# False

# %%
# 함수 endswith  지정한 문자가 끝나는 문자인지 확인하기
s = "Life is too short"
s.endswith("short")
# Out:
# True

# %%
s.endswith("Life")
# Out:
# False
